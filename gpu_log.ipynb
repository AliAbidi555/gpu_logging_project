# %%
import psutil
import subprocess
import time
import csv
from datetime import datetime
import os

games_eng = ['C:\\Program Files (x86)\\Steam\\steamapps','C:\\XboxGames','C:\\Program Files\\EA Games']

def get_gpu_data():
    try:
        output = subprocess.check_output(['nvidia-smi', '--query-gpu=temperature.gpu,utilization.gpu', '--format=csv,noheader,nounits'])
        output = output.decode('utf-8').strip()
        temp, utilization = map(int, output.split(', '))
        return temp, utilization
    except Exception as e:
        return None, None

# Function to get the game process using the most GPU
def get_top_gpu_process():
    try:
        # Get all processes that might be using the GPU
        output = subprocess.check_output(['nvidia-smi', '--query-compute-apps=pid,process_name,used_gpu_memory', '--format=csv,noheader,nounits'])
        processes = output.decode('utf-8').strip().split('\n')

        if processes and processes[0]:
            for process in processes:
                pid, full_path, gpu_memory = process.split(', ')
                process_name = os.path.basename(full_path)

                # Check if the process name contains any of the game paths
                for game_path in games_eng:
                    if game_path in full_path:
                        # Return the base name of the game
                        game_name = os.path.basename(full_path).replace(".exe", "")
                        return game_name, gpu_memory
            return "N/A", 0
        else:
            return "N/A", 0
    except Exception as e:
        return "N/A", 0

# Function to log data
def log_data(file_name):
    with open(file_name, mode='a', newline='') as file:
        writer = csv.writer(file)
        if file.tell() == 0:
            writer.writerow([
                'Timestamp', 'CPU_Usage', 'Memory_Usage', 'RAM_Total', 'RAM_Available',
                'RAM_Used', 'RAM_Percentage', 'Disk_Usage', 'GPU_Temperature', 'GPU_Usage',
                'Bytes_Sent', 'Bytes_Received', 'Top_GPU_Process', 'GPU_Memory_Used_by_Top_Process'
            ])

        while True:
            # Get the current timestamp
            timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

            # Get CPU usage
            cpu_usage = psutil.cpu_percent(interval=1)

            # Get Memory (RAM) usage
            memory_info = psutil.virtual_memory()
            memory_usage = memory_info.percent
            ram_total = memory_info.total
            ram_available = memory_info.available
            ram_used = memory_info.used
            ram_percentage = memory_info.percent

            # Get Disk usage
            disk_usage = psutil.disk_usage('/').percent

            # Get GPU data
            gpu_temp, gpu_usage = get_gpu_data()

            # Get the top GPU-consuming process
            top_process, top_process_gpu_memory = get_top_gpu_process()

            # Get Network statistics
            net_io = psutil.net_io_counters()
            bytes_sent = net_io.bytes_sent
            bytes_received = net_io.bytes_recv

            # Write data to CSV
            writer.writerow([
                timestamp, cpu_usage, memory_usage, ram_total, ram_available,
                ram_used, ram_percentage, disk_usage, gpu_temp, gpu_usage,
                bytes_sent, bytes_received, top_process, top_process_gpu_memory
            ])

            # Flush the file to ensure data is written
            file.flush()
            print(top_process)
            # Adjust sleep time based on whether a GPU-intensive task is running
            if top_process == "N/A":
                time.sleep(10)
            else:
                time.sleep(2)

# Specify the full path to save the CSV file
file_path = r'C:\Users\mohda\Documents\Python Scripts\gpu_logging\system_usage_log_test.csv'

# Start logging data
log_data(file_path)
# Out:
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# Cult Of The Lamb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 103
#     100 file_path = r'C:\Users\mohda\Documents\Python Scripts\gpu_logging\system_usage_log_test.csv'
#     102 # Start logging data
# --> 103 log_data(file_path)
#
# Cell In[20], line 97, in log_data(file_name)
#      95     time.sleep(10)
#      96 else:
# ---> 97     time.sleep(2)
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 6
#       4 for process in processes:
#       5     pid, full_path, gpu_memory = process.split(', ')
# ----> 6     process_name = os.path.basename(full_path)
#       8     # Check if the process name contains any of the game paths
#       9     for game_path in games_eng:
#
# NameError: name 'os' is not defined

# %%
processes
# Out:
# ['64504, [Insufficient Permissions], [N/A]\r',
#  '36140, C:\\Windows\\explorer.exe, [N/A]\r',
#  '41972, C:\\Windows\\SystemApps\\MicrosoftWindows.Client.CBS_cw5n1h2txyewy\\SearchHost.exe, [N/A]\r',
#  '43172, C:\\Windows\\SystemApps\\Microsoft.Windows.StartMenuExperienceHost_cw5n1h2txyewy\\StartMenuExperienceHost.exe, [N/A]\r',
#  '3684, C:\\Program Files\\WindowsApps\\Microsoft.MicrosoftStickyNotes_6.1.2.0_x64__8wekyb3d8bbwe\\Microsoft.Notes.exe, [N/A]\r',
#  '48076, C:\\Windows\\SystemApps\\ShellExperienceHost_cw5n1h2txyewy\\ShellExperienceHost.exe, [N/A]\r',
#  '46300, C:\\Program Files\\ReasonLabs\\Common\\Client\\v1.4.2\\rsAppUI.exe, [N/A]\r',
#  '37152, C:\\Program Files\\ReasonLabs\\Common\\Client\\v1.4.2\\rsAppUI.exe, [N/A]\r',
#  '60880, C:\\Windows\\SystemApps\\Microsoft.LockApp_cw5n1h2txyewy\\LockApp.exe, [N/A]\r',
#  '10164, C:\\Program Files (x86)\\ASUS\\ArmouryDevice\\asus_framework.exe, [N/A]\r',
#  '57464, C:\\Program Files\\NVIDIA Corporation\\NVIDIA GeForce Experience\\NVIDIA Share.exe, [N/A]\r',
#  '16556, C:\\Windows\\SystemApps\\MicrosoftWindows.Client.CBS_cw5n1h2txyewy\\TextInputHost.exe, [N/A]\r',
#  '55368, C:\\Program Files (x86)\\Steam\\bin\\cef\\cef.win7x64\\steamwebhelper.exe, [N/A]\r',
#  '17144, C:\\Users\\mohda\\AppData\\Local\\Discord\\app-1.0.9158\\Discord.exe, [N/A]\r',
#  '29888, C:\\Program Files (x86)\\Steam\\bin\\cef\\cef.win7x64\\steamwebhelper.exe, [N/A]\r',
#  '62312, C:\\Program Files (x86)\\Microsoft\\EdgeWebView\\Application\\127.0.2651.98\\msedgewebview2.exe, [N/A]\r',
#  '48360, C:\\Program Files\\Electronic Arts\\EA Desktop\\EA Desktop\\EADesktop.exe, [N/A]\r',
